# %%
import pandas as pd

# %%
df=pd.read_csv('iriss.csv')

# %%
df.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#        species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sepal_length_cm  150 non-null    float64
#  1   sepal_width_cm   150 non-null    float64
#  2   petal_length_cm  150 non-null    float64
#  3   petal_width_cm   150 non-null    float64
#  4   species          150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# sepal_length_cm    0
# sepal_width_cm     0
# petal_length_cm    0
# petal_width_cm     0
# species            0
# dtype: int64

# %%
df.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      150.000000
# mean          5.843333        3.054000         3.758667        1.198667
# std           0.828066        0.433594         1.764420        0.763161
# min           4.300000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.300000
# 50%           5.800000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %%
for columns in df.columns:
    unique_value=df[columns].nunique()
    print(columns,':',unique_value)
# Out:
# sepal_length_cm : 35
# sepal_width_cm : 23
# petal_length_cm : 43
# petal_width_cm : 22
# species : 3

# %%
for columns in df.columns:
    unique_value=df[columns].unique()
    print(columns,':',unique_value)
# Out:
# sepal_length_cm : [5.1 4.9 4.7 4.6 5.  5.4 4.4 4.8 4.3 5.8 5.7 5.2 5.5 4.5 5.3 7.  6.4 6.9
#  6.5 6.3 6.6 5.9 6.  6.1 5.6 6.7 6.2 6.8 7.1 7.6 7.3 7.2 7.7 7.4 7.9]
# sepal_width_cm : [3.5 3.  3.2 3.1 3.6 3.9 3.4 2.9 3.7 4.  4.4 3.8 3.3 4.1 4.2 2.3 2.8 2.4
#  2.7 2.  2.2 2.5 2.6]
# petal_length_cm : [1.4 1.3 1.5 1.7 1.6 1.1 1.2 1.  1.9 4.7 4.5 4.9 4.  4.6 3.3 3.9 3.5 4.2
#  3.6 4.4 4.1 4.8 4.3 5.  3.8 3.7 5.1 3.  6.  5.9 5.6 5.8 6.6 6.3 6.1 5.3
#  5.5 6.7 6.9 5.7 6.4 5.4 5.2]
# petal_width_cm : [0.2 0.4 0.3 0.1 0.5 0.6 1.4 1.5 1.3 1.6 1.  1.1 1.8 1.2 1.7 2.5 1.9 2.1
#  2.2 2.  2.4 2.3]
# species : ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
numeric=[col for col in df.columns if df.dtypes[col] !='O' ]
numeric
# Out:
# ['sepal_length_cm', 'sepal_width_cm', 'petal_length_cm', 'petal_width_cm']

# %%
categorical=[col for col in df.columns if df.dtypes[col] =='O' ]
categorical
# Out:
# ['species']

# %%
df.sample(7)
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 84               5.4             3.0              4.5             1.5
# 133              6.3             2.8              5.1             1.5
# 92               5.8             2.6              4.0             1.2
# 97               6.2             2.9              4.3             1.3
# 139              6.9             3.1              5.4             2.1
# 58               6.6             2.9              4.6             1.3
# 10               5.4             3.7              1.5             0.2
#
#              species
# 84   Iris-versicolor
# 133   Iris-virginica
# 92   Iris-versicolor
# 97   Iris-versicolor
# 139   Iris-virginica
# 58   Iris-versicolor
# 10       Iris-setosa

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#        species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
sns.countplot(data=df,x='species');

# %%
sns.histplot(df['sepal_length_cm']);

# %%
fig, axes= plt.subplots(2,2, figsize=(12,8))

sns.histplot(df['sepal_length_cm'], kde=True, ax=axes[0,0])
axes[0,0].set_title('Sepal Length')
sns.histplot(df['sepal_width_cm'], kde=True, ax=axes[0,1])
axes[0,1].set_title('Sepal Width')
sns.histplot(df['petal_width_cm'], kde=True, ax=axes[1,1])
axes[1,1].set_title('Petal Width')
sns.histplot(df['petal_length_cm'], kde=True, ax=axes[1,0])
axes[1,0].set_title('Petal Length')
plt.tight_layout();

# %%
sns.scatterplot(data=df, x='sepal_length_cm', y='sepal_width_cm', hue='species');

# %%
sns.scatterplot(data=df, x='petal_length_cm', y='petal_width_cm', hue='species');

# %%
sns.barplot(data=df, y= 'sepal_width_cm', x='species');

# %%
df
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             1.9
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
yes=df[df['species']=='Iris-setosa']
yes['sepal_width_cm'].mean()
# Out:
# 3.418

# %%
sns.pairplot(data=df);
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(data=df, hue='species');
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
irset=df[df['species']=='Iris-setosa']
sns.histplot(irset['sepal_length_cm'], kde=True);

# %%
irver=df[df['species']=='Iris-versicolor']
sns.histplot(irver['sepal_length_cm'], kde=True);

# %%
irvir=df[df['species']=='Iris-virginica']
sns.histplot(irvir['sepal_length_cm'], kde=True);

# %%
df
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# ..               ...             ...              ...             ...
# 145              6.7             3.0              5.2             2.3
# 146              6.3             2.5              5.0             1.9
# 147              6.5             3.0              5.2             2.0
# 148              6.2             3.4              5.4             2.3
# 149              5.9             3.0              5.1             1.8
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
df.corr(numeric_only= True)
# Out:
#                  sepal_length_cm  sepal_width_cm  petal_length_cm  \
# sepal_length_cm         1.000000       -0.109369         0.871754
# sepal_width_cm         -0.109369        1.000000        -0.420516
# petal_length_cm         0.871754       -0.420516         1.000000
# petal_width_cm          0.817954       -0.356544         0.962757
#
#                  petal_width_cm
# sepal_length_cm        0.817954
# sepal_width_cm        -0.356544
# petal_length_cm        0.962757
# petal_width_cm         1.000000

# %%
sns.scatterplot(data=df, x=df['sepal_length_cm'], y=df['sepal_width_cm']);

# %%
sns.scatterplot(data=df, x=df['sepal_length_cm'], y=df['sepal_length_cm']);

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True);

# %%
sns.boxplot(data=df, x='sepal_length_cm');

# %%
sns.boxplot(data=df, x='species', y='sepal_length_cm');

# %%
fig,axes=plt.subplots(2,2, figsize=(12,8))

sns.boxplot(data=df, y= 'species', x='sepal_length_cm', ax=axes[0,0])
axes[0,0].set_title('Sepal Length')

sns.boxplot(data=df, y='species', x='sepal_width_cm', ax=axes[0,1])
axes[0,1].set_title('Sepal Width')

sns.boxplot(data=df, y='species', x='petal_width_cm', ax=axes[1,1])
axes[1,1].set_title('Petal Width')

sns.boxplot(data=df, y='species', x='petal_length_cm', ax=axes[1,0])
axes[1,0].set_title('Petal Length')

plt.tight_layout();
